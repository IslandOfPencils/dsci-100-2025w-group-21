# %%
"hello!"
# Out:
# 'hello!'

# %%
"i will test if i can upload this to github"
# Out:
# 'i will test if i can upload this to github'

# %%
"hi aydin!"
# Out:
# 'hi aydin!'

# %%
'yo wassup'
# Out:
# 'yo wassup'

# %%
curl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 curl
#
# NameError: name 'curl' is not defined

# %%
requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 requests
#
# NameError: name 'requests' is not defined

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 e
#
# NameError: name 'e' is not defined

# %%
#hello this is andrew, nov 8

# %%
#another commit
